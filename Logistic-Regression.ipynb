# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('austin_final.csv')
df.head()
# Out:
#    Serial Number  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0              0         74        60        45             67            49
# 1              1         56        48        39             43            36
# 2              2         58        45        32             31            27
# 3              3         61        46        31             36            28
# 4              4         58        50        41             44            40
#
#    DewPointLowF  HumidityHighPercent  HumidityAvgPercent  HumidityLowPercent  \
# 0            43                   93                  75                  57
# 1            28                   93                  68                  43
# 2            23                   76                  52                  27
# 3            21                   89                  56                  22
# 4            36                   86                  71                  56
#
# ...

# %%
# Threshold should be 0.5?
# No if 0.5, then we will have lot of admits, it will lead to imbalance classifcation problem.
# Avoide the Imbalance Classification Problem.

# %%
# Solve Logistic Regression using SGD method. not learning rate method
# 1. Create a binary classification for score_final to see if there will be rain or not.
# 2. Regress the score_final to see how much rain will be there if there is rain.
